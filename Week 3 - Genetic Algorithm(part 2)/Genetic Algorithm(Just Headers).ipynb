# %% [markdown]
# # Contents
# * Importing Libraries
# * Last Week Recap
# * Crossover
# * Mutation
# * Genetic Algorithm
# * Solving Knapsack(Genetic Algorithm)
# * Solving Knapsack(Brute Force)
# * Visualization
# * Next Week

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from genetic_utils import *
from sklearn.decomposition import PCA

# %% [markdown]
# # Last Week Recap

# %% [markdown]
# Last week, we covered :
# * What is Knapsack problem
# * How to generate a fake Knapsack problem
# * How to design a well-structured chromosome for Knapsack problem
# * Population initialization implementation
# * How to calculate fitness, for Knapsack problem
# * Roulette and Tournament selection implementations

# %% [markdown]
# If you didn't read last week contents, you can find it <a href="https://github.com/Computational-Intelligence-Fall18/Computational-Intelligence-Tutorials/blob/master/Week%202%20-%20Intro%20to%20Genetic%20Algorithm%20Operators/Genetic%20Operators.ipynb">here</a>.

# %% [markdown]
# # Crossover

# %% [markdown]
# ## One Point Crossover

# %% [markdown]
# ![one_point_crossover](figs/one_point_crossover.png)

# %%
def one_point_crossover(pop, selection_method, pc) :
    
    return c1, c2

# %% [markdown]
# ## Two Point Crossover

# %% [markdown]
# ![two_point_crossover](figs/two_point_crossover_v1.jpg)

# %%
def two_point_crossover(pop, selection_method, pc):
    
    return c1, c2

# %% [markdown]
# ## Three Point Crossover

# %% [markdown]
# ![uniform_crossover](figs/uniform-crossover.png)

# %%
def unifrom_crossover(pop, selection_method, pc) :

    return c1, c2

# %% [markdown]
# # Mutation

# %% [markdown]
# ## Random Mutation

# %%
def random_mutation(chrom, pm) :

    return chrom

# %% [markdown]
# ## Inorder Mutation

# %%
def inorder_mutation(chrom, pm, mutation_points) :

    return chrom

# %% [markdown]
# # Genetic Algorithm (Genetic Algorithm)

# %% [markdown]
# ![genetic_architecture](figs/genetic_architecture.PNG)

# %%
def knapsack_genetic_algorithm(pop_size=50, iter_num=10, pm=.4, pc=.3) :
    
    return pop_config, items, bag

# %%
# %%time
pop_size = 60
iter_num = 100
pm = 0
pc = 1
generations, items, bag = knapsack_genetic_algorithm(pop_size, iter_num, pm, pc)
# Out:
# We have 12 items with weight and values of :
# item 0: Weight=>33.77062994324069 Value=>17.78533854675055
# item 1: Weight=>33.890069551365016 Value=>25.738368528682702
# item 2: Weight=>15.375268291707993 Value=>18.70691090357917
# item 3: Weight=>2.2685190926977272 Value=>8.926038196334169
# item 4: Weight=>19.106604692853995 Value=>8.179688837403397
# item 5: Weight=>19.199086895002292 Value=>24.365061863264796
# item 6: Weight=>33.4431505414951 Value=>11.783543883024892
# item 7: Weight=>25.926874882047887 Value=>10.12188481251805
# item 8: Weight=>38.28620635812185 Value=>11.04724619521644
# item 9: Weight=>34.803490334337454 Value=>4.210523412379354
# item 10: Weight=>32.03643007918577 Value=>14.208241358211314
# item 11: Weight=>27.155181204758414 Value=>15.614324386536145
# We have a bag with capacity of 385.90367426844006
# Best fitness in generation 0 : 131.81440011613327
# Best fitness in generation 1 : 131.81440011613327
# Best fitness in generation 2 : 131.81440011613327
# Best fitness in generation 3 : 135.27486286541975
# Best fitness in generation 4 : 142.53419769494698
# Best fitness in generation 5 : 142.53419769494698
# Best fitness in generation 6 : 146.14680834103066
# Best fitness in generation 7 : 150.71388653235036
# Best fitness in generation 8 : 150.71388653235036
# Best fitness in generation 9 : 150.71388653235036
# Best fitness in generation 10 : 157.55060931518744
# Best fitness in generation 11 : 157.55060931518744
# Best fitness in generation 12 : 157.55060931518744
# Best fitness in generation 13 : 157.55060931518744
# Best fitness in generation 14 : 157.55060931518744
# Best fitness in generation 15 : 161.7611327275668
# Best fitness in generation 16 : 161.7611327275668
# Best fitness in generation 17 : 161.7611327275668
# Best fitness in generation 18 : 161.7611327275668
# Best fitness in generation 19 : 161.7611327275668
# Best fitness in generation 20 : 161.7611327275668
# Best fitness in generation 21 : 161.7611327275668
# Best fitness in generation 22 : 161.7611327275668
# Best fitness in generation 23 : 161.7611327275668
# Best fitness in generation 24 : 161.7611327275668
# Best fitness in generation 25 : 161.7611327275668
# Best fitness in generation 26 : 161.7611327275668
# Best fitness in generation 27 : 161.7611327275668
# Best fitness in generation 28 : 161.7611327275668
# Best fitness in generation 29 : 161.7611327275668
# Best fitness in generation 30 : 161.7611327275668
# Best fitness in generation 31 : 161.7611327275668
# Best fitness in generation 32 : 161.7611327275668
# Best fitness in generation 33 : 161.7611327275668
# Best fitness in generation 34 : 161.7611327275668
# Best fitness in generation 35 : 161.7611327275668
# Best fitness in generation 36 : 161.7611327275668
# Best fitness in generation 37 : 161.7611327275668
# Best fitness in generation 38 : 161.7611327275668
# Best fitness in generation 39 : 161.7611327275668
# Best fitness in generation 40 : 161.7611327275668
# Best fitness in generation 41 : 161.7611327275668
# Best fitness in generation 42 : 161.7611327275668
# Best fitness in generation 43 : 161.7611327275668
# Best fitness in generation 44 : 161.7611327275668
# Best fitness in generation 45 : 161.7611327275668
# Best fitness in generation 46 : 161.7611327275668
# Best fitness in generation 47 : 161.7611327275668
# Best fitness in generation 48 : 161.7611327275668
# Best fitness in generation 49 : 161.7611327275668
# Best fitness in generation 50 : 161.7611327275668
# Best fitness in generation 51 : 161.7611327275668
# Best fitness in generation 52 : 161.7611327275668
# Best fitness in generation 53 : 161.7611327275668
# Best fitness in generation 54 : 161.7611327275668
# Best fitness in generation 55 : 161.7611327275668
# Best fitness in generation 56 : 161.7611327275668
# Best fitness in generation 57 : 161.7611327275668
# Best fitness in generation 58 : 161.7611327275668
# Best fitness in generation 59 : 161.7611327275668
# Best fitness in generation 60 : 161.7611327275668
# Best fitness in generation 61 : 161.7611327275668
# Best fitness in generation 62 : 161.7611327275668
# Best fitness in generation 63 : 161.7611327275668
# Best fitness in generation 64 : 161.7611327275668
# Best fitness in generation 65 : 161.7611327275668
# Best fitness in generation 66 : 161.7611327275668
# Best fitness in generation 67 : 161.7611327275668
# Best fitness in generation 68 : 161.7611327275668
# Best fitness in generation 69 : 161.7611327275668
# Best fitness in generation 70 : 161.7611327275668
# Best fitness in generation 71 : 161.7611327275668
# Best fitness in generation 72 : 161.7611327275668
# Best fitness in generation 73 : 161.7611327275668
# Best fitness in generation 74 : 161.7611327275668
# Best fitness in generation 75 : 161.7611327275668
# Best fitness in generation 76 : 161.7611327275668
# Best fitness in generation 77 : 161.7611327275668
# Best fitness in generation 78 : 161.7611327275668
# Best fitness in generation 79 : 161.7611327275668
# Best fitness in generation 80 : 161.7611327275668
# Best fitness in generation 81 : 161.7611327275668
# Best fitness in generation 82 : 161.7611327275668
# Best fitness in generation 83 : 161.7611327275668
# Best fitness in generation 84 : 161.7611327275668
# Best fitness in generation 85 : 161.7611327275668
# Best fitness in generation 86 : 161.7611327275668
# Best fitness in generation 87 : 161.7611327275668
# Best fitness in generation 88 : 161.7611327275668
# Best fitness in generation 89 : 161.7611327275668
# Best fitness in generation 90 : 161.7611327275668
# Best fitness in generation 91 : 161.7611327275668
# Best fitness in generation 92 : 161.7611327275668
# Best fitness in generation 93 : 161.7611327275668
# Best fitness in generation 94 : 161.7611327275668
# Best fitness in generation 95 : 161.7611327275668
# Best fitness in generation 96 : 161.7611327275668
# Best fitness in generation 97 : 161.7611327275668
# Best fitness in generation 98 : 161.7611327275668
# Best fitness in generation 100 : 161.7611327275668
# Wall time: 345 ms

# %% [markdown]
# # Solving Knapsack(Brute Force)

# %%
def calculate_best(items, bag):

    return best_ans

# %%
# %%time
print('Best fitness for Knapsack Problem: {}'.format(calculate_best(items, bag)))
# Out:
# Best fitness for Knapsack Problem: 170.687170923901
# Wall time: 46.8 ms

# %% [markdown]
# # Visualization

# %% [markdown]
# First we will extract the information we needed for visualization :

# %% [markdown]
# We can't visualize high dimensional data, so we use <a href="http://www.iro.umontreal.ca/~pift6080/H09/documents/papers/pca_tutorial.pdf">PCA</a> to map n-D genes of each chromosome to 2-D data

# %% [markdown]
# ## Generations Search Space

# %% [markdown]
# ## Animated Generations Search Space

# %%
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img671653d5b5c54aa49ac7b3fe669c04f9">
#     <br>
#     <input id="_anim_slider671653d5b5c54aa49ac7b3fe669c04f9" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim671653d5b5c54aa49ac7b3fe669c04f9.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim671653d5b5c54aa49ac7b3fe669c04f9.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select671653d5b5c54aa49ac7b3fe669c04f9" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img671653d5b5c54aa49ac7b3fe669c04f9";
#     var slider_id = "_anim_slider671653d5b5c54aa49ac7b3fe669c04f9";
#     var loop_select_id = "_anim_loop_select671653d5b5c54aa49ac7b3fe669c04f9";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAIABJREFUeJzs3Xd8VHW6+PHPOWdKKimkkBAghIRe\
# ooQqIlVsG8W1gIogKKjsWu7eVbbI/nR3r3rXclcRNcoqVtzVXcO6igJSpAgEQQUpCZAQQkjvZer5\
# /RGJhGRSIJnJJM/79fL1YuacM/MkTs4z3/Z8FV3XdYQQQggvo3o6ACGEEOJCSAITQgjhlSSBCSGE\
# 8EqSwIQQQnglSWBCCCG8kiQwIYQQXkkSmBBCCK8kCUwIIYRXkgQmhBDCK0kCE0II4ZUkgQkhhPBK\
# ksCEEEJ4JUlgQgghvJIkMCGEEF5JEpgQQgivJAlMCCGEV5IEJoQQwitJAhNCCOGVJIEJ0YkFBARw\
# /PhxT4chRKckCUx0aWvWrGHcuHH4+/sTERHBuHHjWLlyJbquezq0RqZMmcLrr7/e4LnKykri4uLa\
# /b2Ki4uZPXs2/v7+9OvXj/fee6/d30OIjiYJTHRZzz77LA8++CC//vWvOXPmDHl5ebzyyits374d\
# q9Xq1ljsdrtb368lS5cuxWQykZeXx7vvvst9993HwYMHPR2WEG2jC9EFlZaW6n5+fvqHH37Y7Hm1\
# tbX6r371K71Pnz56RESEvmTJEr26ulrXdV3ftGmT3rt3b/2ZZ57Rw8PD9V69eul/+9vf2nTtU089\
# pUdGRup33HGHXlxcrF977bV6WFiYHhwcrF977bV6dna2ruu6/tvf/lZXVVU3m826v7+/vnTpUl3X\
# dR3Q09PT63+mefPm6WFhYXrfvn31P/7xj7rD4dB1XdffeOMN/bLLLtN/9atf6cHBwXpsbKz+6aef\
# NvkzV1ZW6kajUT9y5Ej9c3fccYf+6KOPXsivWgiPkRaY6JJ27tyJxWLh+uuvb/a8Rx99lKNHj7J/\
# /34yMjLIycnhiSeeqD9+5swZysrKyMnJYdWqVSxdupSSkpJWX1tcXExWVhYpKSk4nU7uuususrKy\
# OHnyJL6+vvziF78A4M9//jOXX345K1asoLKykhUrVjSK9Ze//CVlZWUcP36cLVu28NZbb/HGG2/U\
# H9+1axeDBg2isLCQRx55hEWLFjXZVXr06FE0TWPgwIH1z40aNUpaYML7eDqDCtER3n77bT0yMrLB\
# cxMmTNCDgoJ0Hx8ffcuWLbrT6dT9/Pz0jIyM+nN27Nihx8bG6rpe14ry8fHRbTZb/fHw8HB9586d\
# rbrWaDTqNTU1LmPct2+fHhwcXP/4iiuu0F977bUG5/BjC8xut+smk0k/ePBg/bFXXnlFv+KKK3Rd\
# r2uBDRgwoP5YVVWVDui5ubmN3nfr1q2NfjcpKSn1ryWEtzB4OoEK0RF69uxJYWEhdrsdg6HuY75j\
# xw4AYmJicDqdFBQUUF1dzejRo+uv03Udh8PR4HXOXg/g5+dHZWVlq64NDw/Hx8en/nF1dTUPP/ww\
# 69atq2/FVVRU4HA40DSt2Z+nsLAQq9VKv3796p/r168fOTk59Y979erVIE6omwRyvoCAAMrLyxs8\
# V15eTmBgYLMxCNHZSBei6JImTJiA2WwmNTXV5TlhYWH4+vpy8OBBSktLKS0tpaysrMmb/oVcqyhK\
# g2ueffZZjhw5wq5duygvL2fr1q0A9d18559//vsZjUaysrLqnzt58iS9e/duMdbzDRw4ELvdTnp6\
# ev1z3377LcOGDWvzawnhSZLARJcUHBzMH/7wB+6//34+/PBDKisrcTqd7N+/n6qqKgBUVeWee+7h\
# 4YcfJj8/H4CcnBw+//zzFl//Qq6tqKjA19eX4OBgiouLefzxxxscj4yMdLnmS9M0brnlFn73u99R\
# UVFBVlYWzz33HHfccUerfh/n8vf358Ybb2T58uVUVVWxfft2UlNTmTdvXptfSwhPk

# %% [markdown]
# # Fitness Value Through Generations

# %% [markdown]
# # Next Week

# %% [markdown]
# Next week, we will implement :
# * Multi Parent Crossovers
# * Crossover Hillclimbing
# * Geometrical Crossover
# * Uniform Mutation for floating point genes
# * Macromutation – Headless Chicken
# * How to solve new problem
